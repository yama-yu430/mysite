# %% [markdown]
# <a href="https://colab.research.google.com/github/yama-yu430/mysite/blob/submit/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def animal_finger_game():
    animals = {
        "犬": 5,
        "猫": 5,
        "ライオン": 5,
        "トラ": 5,
        "クマ": 5,
        "パンダ": 5,
        "サル": 5,
        "ゴリラ": 5,
        "チンパンジー": 5,
        "オランウータン": 5,
        "馬": 1,
        "牛": 4,
        "豚": 4,
        "象": 5,
        "サイ": 3,
        "カバ": 4,
        "キリン": 2,
        "シマウマ": 1,
        "カンガルー": 5,
        "コアラ": 5,
        "タヌキ": 5,
        "キツネ": 5,
        "オオカミ": 5,
        "イノシシ": 4,
        "ニホンジカ": 4,
        "ウサギ": 5,
        "リス": 5,
        "モグラ": 5,
        "ハリネズミ": 5,
        "コウモリ": 5,
        "ネズミ": 5,
        "アルマジロ": 5,
        "ナマケモノ": 2,
        "アリクイ": 5,
        "センザンコウ": 5,
        "ビーバー": 5,
        "カワウソ": 5,
        "アライグマ": 5,
        "スカンク": 5,
        "フェレット": 5,
        "ミーアキャット": 4,
        "プレーリードッグ": 5,
        "ハムスター": 5,
        "モルモット": 5,
        "チンチラ": 5,
        "デグー": 5,
        "シマリス": 5,
        "フクロモモンガ": 5,
        "モモンガ": 5,
        "ムササビ": 5,
        "コンドル": 4,
        "ワシ": 4,
        "タカ": 4,
        "フクロウ": 4,
        "ミミズク": 4,
        "ハヤブサ": 4,
        "インコ": 4,
        "オウム": 4,
        "セキセイインコ": 4,
        "オカメインコ": 4,
        "文鳥": 4,
        "ジュウシマツ": 4,
        "カナリア": 4,
        "十姉妹": 4,
        "キンカチョウ": 4,
        "ブンチョウ": 4,
        "スズメ": 4,
        "ツバメ": 4,
        "カラス": 4,
        "ハト": 4,
        "ニワトリ": 4,
        "アヒル": 3,
        "ガチョウ": 3,
        "シチメンチョウ": 4,
        "フラミンゴ": 3,
        "ペンギン": 3,
        "ダチョウ": 2,
        "エミュー": 3,
        "ヒクイドリ": 3,
        "ペリカン": 4,
        "アホウドリ": 4,
        "カモメ": 4,
        "ウミネコ": 4,
        "コブハクチョウ": 3,
        "コクチョウ": 3,
        "オオハクチョウ": 3,
        "コハクチョウ": 3,
        "マガモ": 3,
        "カルガモ": 3,
        "オシドリ": 3,
        "カワセミ": 4,
        "ヤマセミ": 4,
        "アカショウビン": 4,
        "アオショウビン": 4,
        "ヤイロチョウ": 4,
        "ブッポウソウ": 4,
        "サイチョウ": 4,
        "キツツキ": 4,
        "アオゲラ": 4,
        "クマゲラ": 4,
        "アカゲラ": 4,
        "コゲラ": 4,
        "ミドリカラスモドキ": 4,
        "カカポ": 4,
        "ドードー": 4,
        "モア": 4,
        "リョコウバト": 4,
        "オオウミガラス": 4,
        "エグリプトテラ": 4,
        "ティラノサウルス": 3,
        "トリケラトプス": 5,
        "ステゴサウルス": 5,
        "ブラキオサウルス": 5,
        "アロサウルス": 3,
        "ヴェロキラプトル": 3,
        "プテラノドン": 4,
        "モササウルス": 5,
        "イクチオサウルス": 5,
        "プレシオサウルス": 5,
        "ワニ": 5,
        "ヘビ": 0,
        "トカゲ": 5,
        "カメ": 5,
        "カメレオン": 5,
        "ヤモリ": 5,
        "小人": 5
    }

    while True:
        animal, correct_fingers = random.choice(list(animals.items()))

        print(f"{animal}の指の数はいくつでしょう？")

        while True:
            guess_input = input("指の数を入力してください（ヒントは「h」）：").lower()

            if guess_input == 'h':
                # 提供できるヒントが数字の場合のみヒントを出す
                if isinstance(correct_fingers, int):
                    hint_type = random.randint(1, 3)
                    if hint_type == 1:
                        if correct_fingers > 5:
                            print("ヒント：指の数は5より多いです。")
                        elif correct_fingers < 5:
                            print("ヒント：指の数は5より少ないです。")
                        else:
                            print("ヒント：指の数は5です。")
                    elif hint_type == 2:
                        # 動物の特徴に関するヒントは、動物の種類によって内容が変わるため、簡単な例をいくつか示します。
                        # ここでは一般的なヒントとしています。必要に応じて動物ごとのヒントを追加してください。
                        print("ヒント：その動物がどんな姿をしているか想像してみましょう。")
                    elif hint_type == 3:
                         if correct_fingers > 0:
                            lower_bound = max(0, correct_fingers - random.randint(1, 3))
                            upper_bound = correct_fingers + random.randint(1, 3)
                            print(f"ヒント：指の数は {lower_bound} から {upper_bound} の間かもしれません。")
                         else:
                             print("ヒント：指の数は0です。")
                else:
                    print("この動物の指の数は数字ではありません。ヒントは出せません。")
                continue

            try:
                guess = int(guess_input)
                if guess == correct_fingers:
                    print("正解です！")
                    while True:
                        play_again = input("もう一度挑戦しますか？（y/n）: ").lower()
                        if play_again == "y":
                            break
                        elif play_again == "n":
                            print("また遊んでね！")
                            return
                        else:
                            print("無効な入力です。「y」または「n」で答えてください。")
                    break
                else:
                    print("不正解です。")
                    while True:
                        try_again = input("もう一度挑戦しますか？（y/n）: ").lower()
                        if try_again == "y":
                            break
                        elif try_again == "n":
                            print(f"正解は {correct_fingers} です。")
                            print("また遊んでね！")
                            return
                        else:
                            print("無効な入力です。「y」または「n」で答えてください。")

            except ValueError:
                print("無効な入力です。数字または「h」を入力してください。")

animal_finger_game()
# Out:
# コハクチョウの指の数はいくつでしょう？
# 指の数を入力してください（ヒントは「h」）：h
# ヒント：その動物がどんな姿をしているか想像してみましょう。
# 指の数を入力してください（ヒントは「h」）：6
# 不正解です。
# もう一度挑戦しますか？（y/n）: y
# 指の数を入力してください（ヒントは「h」）：h
# ヒント：指の数は 0 から 6 の間かもしれません。
# 指の数を入力してください（ヒントは「h」）：4
# 不正解です。
# もう一度挑戦しますか？（y/n）: y
# 指の数を入力してください（ヒントは「h」）：5
# 不正解です。
# もう一度挑戦しますか？（y/n）: y
# 指の数を入力してください（ヒントは「h」）：2
# 不正解です。
# もう一度挑戦しますか？（y/n）: h
# 無効な入力です。「y」または「n」で答えてください。
# もう一度挑戦しますか？（y/n）: y
# 指の数を入力してください（ヒントは「h」）：h
# ヒント：その動物がどんな姿をしているか想像してみましょう。
# 指の数を入力してください（ヒントは「h」）：0
# 不正解です。
# もう一度挑戦しますか？（y/n）: 1
# 無効な入力です。「y」または「n」で答えてください。
# もう一度挑戦しますか？（y/n）: 3
# 無効な入力です。「y」または「n」で答えてください。
# もう一度挑戦しますか？（y/n）: y
# 指の数を入力してください（ヒントは「h」）：3
# 正解です！
# もう一度挑戦しますか？（y/n）: n
# また遊んでね！

# %% [markdown]
# # 新しいセクション
